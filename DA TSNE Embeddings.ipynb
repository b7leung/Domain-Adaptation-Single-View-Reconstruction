# %%
# %load_ext autoreload
# %autoreload 2

# %%
from config import cfg

import os
cfg.CONST.DEVICE = "3"
# need to set gpus before anything involving pytorch
os.environ["CUDA_VISIBLE_DEVICES"] = cfg.CONST.DEVICE

from core.train import train_net
from core.test import test_net
import torch
import pprint
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np

# %%
def embed_TSNE(data):
    X_embedded = data
    X_embedded = PCA(n_components = 50, svd_solver='auto').fit_transform(X_embedded)
    X_embedded = TSNE(n_components=2).fit_transform(X_embedded) 
    return X_embedded

def visualize_tsne(embedded_latent_vectors, class_labels, title="TSNE"):
    
    embedded_df = pd.DataFrame(embedded_latent_vectors) 
    ax = embedded_df.plot.scatter(x=0, y = 1, c = class_labels, colormap="viridis")
    ax.set_title(title)

# %%
trial_name = "2020_03_19--18_54_21_OOWL_DA_CORAL_lam_10_TRAIN"
weights_path = "./output/CORAL/{}/checkpoints/best-ckpt.pth".format(trial_name)

#trial_name = "2020_03_21--01_49_04_OWILDVoxelCls_VoxLamExp_DANNlam1_TRAIN"
#weights_path = "./output/{}/checkpoints/best-ckpt.pth".format(trial_name)

#weights_path = "./output/author_saved_params/Pix2Vox-A-ShapeNet.pth"

cfg.CONST.WEIGHTS = weights_path

# obtaining latent vectors for target domain
cfg.DATASET.CLASSES_TO_USE = ["aeroplane", "car", "display", "lamp", "telephone", "watercraft"]
cfg.DATASET.TEST_DATASET = "OWILD"
cfg.TEST.USE_TRAIN_SET = False
cfg.CONST.N_VIEWS_RENDERING = 8
_, t_class_labels, t_latent_vectors = test_net(cfg)
t_embedded = embed_TSNE(t_latent_vectors)
# Out:
# [INFO] 2020-03-21 16:37:16.134492 Collecting files of Taxonomy[ID=Airplane_Model, Name=Airplane_Model]
# [INFO] 2020-03-21 16:37:16.137018 Collecting files of Taxonomy[ID=Boat_Model, Name=Boat_Model]
# [INFO] 2020-03-21 16:37:16.139046 Collecting files of Taxonomy[ID=Car_Model, Name=Car_Model]
# [INFO] 2020-03-21 16:37:16.140185 Collecting files of Taxonomy[ID=Lamp, Name=Lamp]
# [INFO] 2020-03-21 16:37:16.142078 Collecting files of Taxonomy[ID=Monitor, Name=Monitor]
# [INFO] 2020-03-21 16:37:16.143739 Collecting files of Taxonomy[ID=Telephone, Name=Telephone]
# [INFO] 2020-03-21 16:37:16.145167 Complete collecting files of the dataset. Total files: 19.
# [INFO] 2020-03-21 16:37:20.490449 Loading weights from ./output/CORAL/2020_03_19--18_54_21_OOWL_DA_CORAL_lam_10_TRAIN/checkpoints/best-ckpt.pth ...

# %%
cfg.DATASET.CLASSES_TO_USE = ["aeroplane", "car", "display", "lamp", "telephone", "watercraft"]
cfg.DATASET.TEST_DATASET = "ShapeNet"
cfg.CONST.N_VIEWS_RENDERING=1
# obtaining latent vectors for ShapeNet source domain

_, s_class_labels, s_latent_vectors = test_net(cfg)
s_embedded = embed_TSNE(s_latent_vectors)
# Out:
# [INFO] 2020-03-21 16:37:26.130802 Loading cache of Taxonomy[ID=02691156, Name=aeroplane, Partition=test]
# [INFO] 2020-03-21 16:37:26.142419 Loading cache of Taxonomy[ID=02958343, Name=car, Partition=test]
# [INFO] 2020-03-21 16:37:26.162109 Loading cache of Taxonomy[ID=03211117, Name=display, Partition=test]
# [INFO] 2020-03-21 16:37:26.165325 Loading cache of Taxonomy[ID=03636649, Name=lamp, Partition=test]
# [INFO] 2020-03-21 16:37:26.170211 Loading cache of Taxonomy[ID=04401088, Name=telephone, Partition=test]
# [INFO] 2020-03-21 16:37:26.172894 Loading cache of Taxonomy[ID=04530566, Name=watercraft, Partition=test]
# [INFO] 2020-03-21 16:37:26.176949 Complete collecting files of the dataset. Total files: 3596.
# [INFO] 2020-03-21 16:37:29.466428 Loading weights from ./output/CORAL/2020_03_19--18_54_21_OOWL_DA_CORAL_lam_10_TRAIN/checkpoints/best-ckpt.pth ...
# ============================ TEST RESULTS ============================
# Taxonomy	#Sample	Baseline	t=0.20	t=0.30	t=0.40	t=0.50
# aeroplane	810	0.5130		0.6139	0.6368	0.6377	0.6218
# car     	1501	0.7980		0.8273	0.8432	0.8485	0.8459
# display 	220	0.4680		0.4842	0.4971	0.4968	0.4824
# lamp    	465	0.3810		0.4526	0.4471	0.4322	0.4101
# telephone	211	0.6610		0.7309	0.7459	0.7555	0.7593
# watercraft	389	0.5130		0.5812	0.5952	0.5926	0.5770
# Overall 				0.6775	0.6918	0.6925	0.6827

# %%
# show TSNE for source and target domains
s_t_embedded = np.concatenate((s_embedded, t_embedded), axis =0)
domain_labels = [0 for i in range(s_embedded.shape[0])] + [1 for i in range(t_embedded.shape[0])]
visualize_tsne(s_t_embedded, domain_labels, "Source and Target Domain t-SNE")

# %%
# show TSNE, class based for source domain
visualize_tsne(s_embedded, s_class_labels, "Source Domain t-SNE")

# %%
# show TSNE, class based for source domain
visualize_tsne(t_embedded, t_class_labels, "Target Domain t-SNE")
